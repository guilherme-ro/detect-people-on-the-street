# %% [markdown]
# <a href="https://colab.research.google.com/github/guilherme-ro/detect-people-on-the-street/blob/main/detec%C3%A7%C3%A3o_pessoas_rua.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing Dependencies
print("--- Installing the official Ultralytics library (YOLOv8) ---")
# !pip install ultralytics

# Ensuring the environment is ready for video detection
# !pip install opencv-python

print("\n--- Instalação Concluída. ---")
# Out:
# --- Instalando a biblioteca oficial Ultralytics (YOLOv8) ---
# Collecting ultralytics
#   Downloading ultralytics-8.3.204-py3-none-any.whl.metadata (37 kB)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.0.2)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (3.10.0)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (4.12.0.88)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (11.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (6.0.3)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.32.4)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.16.2)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (2.8.0+cu126)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from ultralytics) (0.23.0+cu126)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: polars in /usr/local/lib/python3.12/dist-packages (from ultralytics) (1.25.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.17-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.23.0->ultralytics) (2025.8.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.8.0->ultralytics) (3.4.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.3)
# Downloading ultralytics-8.3.204-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 58.7 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.17-py3-none-any.whl (28 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.204 ultralytics-thop-2.0.17
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
#
# --- Instalação Concluída. ---

# %%
# Execução da Detecção de Pessoas

import os
from ultralytics import YOLO

# Confirmação do nome do vídeo e caminho local
input_video_file = "video_rua.mp4"
data_path = "data"

# Caminho completo do vídeo de entrada
input_video_path = os.path.join(data_path, input_video_file)

# Carrega o modelo YOLOv8
print("--- Carregando o modelo YOLOv8n... ---")
model = YOLO('yolov8n.pt')

# Configura e executa a detecção de vídeo
# A classe '0' (zero) no dataset COCO (usado pelo YOLO) corresponde a 'person' (pessoa).
print(f"\n--- Iniciando Detecção de Pessoas em {input_video_file}... ---")

# O método 'track' faz a detecção e o rastreamento, ótimo para vídeos.
results = model.track(
    source=input_video_path,
    save=True,           # Salva o vídeo de saída
    show=False,          # Não exibe na tela (impossível no Colab)
    conf=0.40,           # Nível de confiança mínimo (40%)
    classes=[0],         # Filtra para detectar APENAS a classe 0 (Pessoa)
    project='runs/detect', # Pasta onde o resultado será salvo
    name='predict',      # Subpasta onde o resultado final estará
    exist_ok=True,       # Permite reescrever se a pasta já existe
    tracker="botsort.yaml" # Usa um rastreador para melhor estabilidade
)

# Informa o resultado
output_dir = os.path.join('runs', 'detect', 'predict')
output_files = os.listdir(output_dir)
output_video_name = [f for f in output_files if f.endswith('.mp4') or f.endswith('.avi')][0] if output_files else "N/A"

print(f"\n" + "="*70)
print(f"       ✅ DETECÇÃO DE PESSOAS CONCLUÍDA ✅       ")
print(f"O vídeo processado foi salvo em: runs/detect/predict/{output_video_name}")
print("Você pode baixar o arquivo .mp4 dessa pasta no painel de arquivos do Colab.")
print("======================================================================")
# Out:
# --- Carregando o modelo YOLOv8n... ---
#
# --- Iniciando Detecção de Pessoas em video_rua.mp4... ---
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.2ms
# video 1/1 (frame 2/6099) /content/data/video_rua.mp4: 384x640 4 persons, 8.8ms
# video 1/1 (frame 3/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 4/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.0ms
# video 1/1 (frame 5/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.0ms
# video 1/1 (frame 6/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 7/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 8/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.8ms
# video 1/1 (frame 9/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.5ms
# video 1/1 (frame 10/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.4ms
# video 1/1 (frame 11/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.9ms
# video 1/1 (frame 12/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 13/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 14/6099) /content/data/video_rua.mp4: 384x640 4 persons, 9.8ms
# video 1/1 (frame 15/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.5ms
# video 1/1 (frame 16/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.6ms
# video 1/1 (frame 17/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.5ms
# video 1/1 (frame 18/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 19/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.2ms
# video 1/1 (frame 20/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.2ms
# video 1/1 (frame 21/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.2ms
# video 1/1 (frame 22/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.3ms
# video 1/1 (frame 23/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.2ms
# video 1/1 (frame 24/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.3ms
# video 1/1 (frame 25/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 26/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.3ms
# video 1/1 (frame 27/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.6ms
# video 1/1 (frame 28/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.8ms
# video 1/1 (frame 29/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.1ms
# video 1/1 (frame 30/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 31/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.4ms
# video 1/1 (frame 32/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.2ms
# video 1/1 (frame 33/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.3ms
# video 1/1 (frame 34/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.6ms
# video 1/1 (frame 35/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 36/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.6ms
# video 1/1 (frame 37/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 38/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 39/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.8ms
# video 1/1 (frame 40/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 41/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 42/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.7ms
# video 1/1 (frame 43/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 44/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.8ms
# video 1/1 (frame 45/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 46/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 47/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 48/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 49/6099) /content/data/video_rua.mp4: 384x640 4 persons, 8.9ms
# video 1/1 (frame 50/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 51/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.8ms
# video 1/1 (frame 52/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 53/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.0ms
# video 1/1 (frame 54/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 55/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 56/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.9ms
# video 1/1 (frame 57/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.7ms
# video 1/1 (frame 58/6099) /content/data/video_rua.mp4: 384x640 4 persons, 7.5ms
# video 1/1 (frame 59/6099) /content/data/video_rua.mp4: 384x640 4 persons, 5.9ms
# video 1/1 (frame 60/6099) /content/data/video_rua.mp4: 384x640 4 persons, 6.1ms
# video 1/1 (frame 61/6099) /content/data/video_rua.mp4: 384x640 2 persons, 7.4ms
# video 1/1 (frame 62/6099) /content/data/video_rua.mp4: 384x640 2 persons, 11.7ms
# video 1/1 (frame 63/6099) /content/data/video_rua.mp4: 384x640 2 persons, 6.5ms
# video 1/1 (frame 64/6099) /content/data/video_rua.mp4: 384x640 2 persons, 6.1ms
# video 1/1 (frame 65/6099) /content/data/video_rua.mp4: 384x640 2 persons, 7.0ms
# video 1/1 (frame 66/6099) /content/data/video_rua.mp4: 384x640 2 persons, 6.0ms
# video 1/1 (frame 67/6099) /content/data/video_rua.mp4: 384x640 2 persons, 5.9ms
# video 1/1 (frame 68/6099) /content/data/video_rua.mp4: 384x640 2 persons, 6.7ms
# video 1/1 (frame 69/6099) /content/data/video_rua.mp4: 384x640 2 persons, 5.8ms
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1147230542.py in <cell line: 0>()
#      20
#      21 # O método 'track' faz a detecção e o rastreamento, ótimo para vídeos.
# ---> 22 results = model.track(
#      23     source=input_video_path,
#      24     save=True,           # Salva o vídeo de saída
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in track(self, source, stream, persist, **kwargs)
#     599         kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     600         kwargs["mode"] = "track"
# --> 601         return self.predict(source=source, stream=stream, **kwargs)
#     602
#     603     def val(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     555         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     556             self.predictor.set_prompts(prompts)
# --> 557         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#     558
#     559     def track(
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in __call__(self, source, model, stream, *args, **kwargs)
#     227             return self.stream_inference(source, model, *args, **kwargs)
#     228         else:
# --> 229             return list(self.stream_inference(source, model, *args, **kwargs))  # merge list of Result into one
#     230
#     231     def predict_cli(self, source=None, model=None):
#
# /usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py in generator_context(*args, **kwargs)
#      57                     # Pass the last request to the generator and get its response
#      58                     with ctx_factory():
# ---> 59                         response = gen.send(request)
#      60
#      61         # We let the exceptions raised above by the generator's `.throw` or
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in stream_inference(self, source, model, *args, **kwargs)
#     334                 # Inference
#     335                 with profilers[1]:
# --> 336                     preds = self.inference(im, *args, **kwargs)
#     337                     if self.args.embed:
#     338                         yield from [preds] if isinstance(preds, torch.Tensor) else preds  # yield embedding tensors
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/predictor.py in inference(self, im, *args, **kwargs)
#     182             else False
#     183         )
# --> 184         return self.model(im, augment=self.args.augment, visualize=visualize, embed=self.args.embed, *args, **kwargs)
#     185
#     186     def pre_transform(self, im: list[np.ndarray]) -> list[np.ndarray]:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/autobackend.py in forward(self, im, augment, visualize, embed, **kwargs)
#     635         # PyTorch
#     636         if self.pt or self.nn_module:
# --> 637             y = self.model(im, augment=augment, visualize=visualize, embed=embed, **kwargs)
#     638
#     639         # TorchScript
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in forward(self, x, *args, **kwargs)
#     137         if isinstance(x, dict):  # for cases of training and validating while training.
#     138             return self.loss(x, *args, **kwargs)
# --> 139         return self.predict(x, *args, **kwargs)
#     140
#     141     def predict(self, x, profile=False, visualize=False, augment=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in predict(self, x, profile, visualize, augment, embed)
#     155         if augment:
#     156             return self._predict_augment(x)
# --> 157         return self._predict_once(x, profile, visualize, embed)
#     158
#     159     def _predict_once(self, x, profile=False, visualize=False, embed=None):
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py in _predict_once(self, x, profile, visualize, embed)
#     178             if profile:
#     179                 self._profile_one_layer(m, x, dt)
# --> 180             x = m(x)  # run
#     181             y.append(x if m.i in self.save else None)  # save output
#     182             if visualize:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/block.py in forward(self, x)
#     317         y = list(self.cv1(x).chunk(2, 1))
#     318         y.extend(m(y[-1]) for m in self.m)
# --> 319         return self.cv2(torch.cat(y, 1))
#     320
#     321     def forward_split(self, x: torch.Tensor) -> torch.Tensor:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/nn/modules/conv.py in forward_fuse(self, x)
#      91             (torch.Tensor): Output tensor.
#      92         """
# ---> 93         return self.act(self.conv(x))
#      94
#      95
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1771             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1772         else:
# -> 1773             return self._call_impl(*args, **kwargs)
#    1774
#    1775     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1782                 or _global_backward_pre_hooks or _global_backward_hooks
#    1783                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1784             return forward_call(*args, **kwargs)
#    1785
#    1786         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/activation.py in forward(self, input)
#     432
#     433     def forward(self, input: Tensor) -> Tensor:
# --> 434         return F.silu(input, inplace=self.inplace)
#     435
#     436     def extra_repr(self) -> str:
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/functional.py in silu(input, inplace)
#    2372         return handle_torch_function(silu, (input,), input, inplace=inplace)
#    2373     if inplace:
# -> 2374         return torch._C._nn.silu_(input)
#    2375     return torch._C._nn.silu(input)
#    2376
#
# KeyboardInterrupt:
